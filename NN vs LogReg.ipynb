# %%
# Import depen
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
diabetes_df = pd.read_csv('Resources/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target
y = diabetes_df.Outcome
X = diabetes_df.drop('Outcome', 1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
# Split training/test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for NN
# Create a StandardScaler instance
scaler=StandardScaler()

#Fit the Scaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# REGRESSION MODEL

log_classifier = LogisticRegression(solver='lbfgs', max_iter=200)

#Train
log_classifier.fit(X_train, y_train)

#Evaluate
y_pred = log_classifier.predict(X_test)
print(f' Logistic regression model accuracy: {accuracy_score(y_test, y_pred):.3f}')
# Out:
#  Logistic regression model accuracy: 0.729

# %%
#NN MODEL
nn_model= tf.keras.models.Sequential()
nn_model.add(
    tf.keras.layers.Dense(units=16, 
                          activation='relu',
                         input_dim=8)
)
nn_model.add(
    tf.keras.layers.Dense(units=1, 
                          activation='sigmoid',
                         )
)

#Compile Sequential and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# Train
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

#Evaluate
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 652us/step - loss: 0.6770 - accuracy: 0.5986
# Epoch 2/50
# 18/18 [==============================] - 0s 665us/step - loss: 0.6517 - accuracy: 0.6571
# Epoch 3/50
# 18/18 [==============================] - 0s 639us/step - loss: 0.6171 - accuracy: 0.6999
# Epoch 4/50
# 18/18 [==============================] - 0s 676us/step - loss: 0.5711 - accuracy: 0.7470
# Epoch 5/50
# 18/18 [==============================] - 0s 725us/step - loss: 0.5575 - accuracy: 0.7759
# Epoch 6/50
# 18/18 [==============================] - 0s 705us/step - loss: 0.5343 - accuracy: 0.7719
# Epoch 7/50
# 18/18 [==============================] - 0s 739us/step - loss: 0.5329 - accuracy: 0.7841
# Epoch 8/50
# 18/18 [==============================] - 0s 681us/step - loss: 0.5111 - accuracy: 0.7672
# Epoch 9/50
# 18/18 [==============================] - 0s 722us/step - loss: 0.4991 - accuracy: 0.7988
# Epoch 10/50
# 18/18 [==============================] - 0s 722us/step - loss: 0.5005 - accuracy: 0.7952
# Epoch 11/50
# 18/18 [==============================] - 0s 689us/step - loss: 0.4793 - accuracy: 0.8282
# Epoch 12/50
# 18/18 [==============================] - 0s 665us/step - loss: 0.4843 - accuracy: 0.8119
# Epoch 13/50
# 18/18 [==============================] - 0s 677us/step - loss: 0.4331 - accuracy: 0.8412
# Epoch 14/50
# 18/18 [==============================] - 0s 749us/step - loss: 0.5119 - accuracy: 0.7606
# Epoch 15/50
# 18/18 [==============================] - 0s 717us/step - loss: 0.4970 - accuracy: 0.7778
# Epoch 16/50
# 18/18 [==============================] - 0s 703us/step - loss: 0.4560 - accuracy: 0.8010
# Epoch 17/50
# 18/18 [==============================] - 0s 688us/step - loss: 0.4660 - accuracy: 0.7888
# Epoch 18/50
# 18/18 [==============================] - 0s 720us/step - loss: 0.4612 - accuracy: 0.7864
# Epoch 19/50
# 18/18 [==============================] - 0s 711us/step - loss: 0.4722 - accuracy: 0.7759
# Epoch 20/50
# 18/18 [==============================] - 0s 702us/step - loss: 0.4379 - accuracy: 0.8071
# Epoch 21/50
# 18/18 [==============================] - 0s 639us/step - loss: 0.4705 - accuracy: 0.7729
